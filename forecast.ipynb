# %%
from backtester import Backtester
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

stock = 'UAL'

if __name__ == "__main__":
    gbm_params = {
        'threshold': 2,
        'time_periods': 90,
        'num_simulations': 10000,
    }
    backtester = Backtester(stock, 'SMART', 'USD')
    backtester.forecast_1_day_1yr(gbm_params)
    backtester.forecast_1_day_3m(gbm_params)
    backtester.forecast_15_mins(gbm_params)
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Loading historical data from cache...
# Loading historical data from cache...
# Loading historical data from cache...
# mu_mean: 0.8916, mu_std: 0.4367
# sigma_mean: 0.4367, sigma_std: 0.1326
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# 95% Confidence Interval:
# Lower Bound: 95.57
# Upper Bound: 105.32
#
# Coverage Probability: 0.95
# Number of Simulations Above Upper Bound: 253
# Number of Simulations Below Lower Bound: 219
# mu_mean: 2.9592, mu_std: 0.4300
# sigma_mean: 0.4300, sigma_std: 0.0733
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# 95% Confidence Interval:
# Lower Bound: 62.91
# Upper Bound: 139.61
#
# Coverage Probability: 0.95
# Number of Simulations Above Upper Bound: 386
# Number of Simulations Below Lower Bound: 67
# mu_mean: 0.0974, mu_std: 0.0837
# sigma_mean: 0.0837, sigma_std: 0.0417
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# 95% Confidence Interval:
# Lower Bound: 95.78
# Upper Bound: 97.22
#
# Coverage Probability: 0.96
# Number of Simulations Above Upper Bound: 236
# Number of Simulations Below Lower Bound: 204
