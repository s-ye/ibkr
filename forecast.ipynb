# %%
from backtester import Backtester
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

stock = 'SG'

if __name__ == "__main__":
    gbm_params = {
        'threshold': 2,
        'time_periods': 90,
        'num_simulations': 50000,
    }
    backtester = Backtester(stock, 'SMART', 'USD')
    data = backtester.one_yr_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)

    data = backtester.three_mo_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)
# Out:
# Loading historical data from cache...
# Loading historical data from cache...
# Loading historical data from cache...
# mu_mean: 1.1498, mu_std: 0.4037
# sigma_mean: 0.4037, sigma_std: 0.1123
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# Start Price: 125.0
# 95% Confidence Interval:
# Lower Bound: 83.77
# Upper Bound: 306.72
#
# Coverage Probability: 0.96
# Number of Simulations Above Upper Bound: 1990
# Number of Simulations Below Lower Bound: 100
# mu_mean: 2.3573, mu_std: 0.3687
# sigma_mean: 0.3687, sigma_std: 0.0423
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# ...
