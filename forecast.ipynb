# %%
from backtester import Backtester
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

stock = 'SG'

if __name__ == "__main__":
    gbm_params = {
        'threshold': 2,
        'time_periods': 90,
        'num_simulations': 50000,
    }
    backtester = Backtester(stock, 'SMART', 'USD')
    data = backtester.one_yr_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)

    data = backtester.three_mo_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)
# Out:
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Loading historical data from cache...
# Loading historical data from cache...
# Loading historical data from cache...
# r-hat: 0.005072503714853008, sigma-hat: 0.050969908086975727
# mu: 1.2795699019081554, sigma: 0.8091222068757462
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# Start Price: 36.83
# 95% Confidence Interval:
# Lower Bound: 34.68
# Upper Bound: 39.21
#
# Coverage Probability: 0.95
# Number of Simulations Above Upper Bound: 1301
# Number of Simulations Below Lower Bound: 1021
# r-hat: 0.0021618672115139765, sigma-hat: 0.04114499922601398
# mu: 0.5456369927821765, sigma: 0.6531566138758683
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# Start Price: 36.83
# 95% Confidence Interval:
# Lower Bound: 35.02
# Upper Bound: 38.80
#
# Coverage Probability: 0.95
# Number of Simulations Above Upper Bound: 1240
# Number of Simulations Below Lower Bound: 1072
