# %%
from backtester import Backtester
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

stock = 'SG'

if __name__ == "__main__":
    gbm_params = {
        'threshold': 2,
        'time_periods': 90,
        'num_simulations': 50000,
    }
    backtester = Backtester(stock, 'SMART', 'USD')
    data = backtester.one_yr_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)

    data = backtester.three_mo_1d_data
    simulations, associated_mu, associated_sigma, forecast_dates = backtester.forecast_data(gbm_params, data)
# Out:
# Loading historical data from cache...
# Loading historical data from cache...
# Loading historical data from cache...
# mu_mean: 1.2783, mu_std: 0.8107
# sigma_mean: 0.8107, sigma_std: 0.2645
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# Start Price: 36.83
# 95% Confidence Interval:
# Lower Bound: -15.28
# Upper Bound: 152.03
#
# Coverage Probability: 0.96
# Number of Simulations Above Upper Bound: 2204
# Number of Simulations Below Lower Bound: 0
# mu_mean: 0.5448, mu_std: 0.6585
# sigma_mean: 0.6585, sigma_std: 0.1041
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 500 tune and 1_000 draw iterations (2_000 + 4_000 draws total) took 1 seconds.
# Start Price: 36.83
# 95% Confidence Interval:
# Lower Bound: -22.32
# Upper Bound: 130.85
#
# Coverage Probability: 0.96
# Number of Simulations Above Upper Bound: 2167
# Number of Simulations Below Lower Bound: 0
